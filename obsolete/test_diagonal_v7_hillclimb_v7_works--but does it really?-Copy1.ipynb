# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

#datadir = '/home/mer49/Dropbox (Cambridge University)/Shared/Prannoy/Code/20200317 MER GPs/'
datadir = "/home/cfs/mer49/gp/"

from util            import *
from basics          import *
from simulate_data   import *
from estimators      import *
from config          import *
from scipy.special   import *
from functools       import lru_cache as cache
from opt_einsum      import contract
from scipy.io        import loadmat
from IPython.display import clear_output
configure_pylab()

# This code benefits considerably from using single-precision floating point
# Jax's fft is slow
# Numpy's fft pathologically casts to float64
# Scipy's seems ok
from scipy.fft import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Set constants

# %%
tol    = 1e-4      # Newton convergence tolerance
mintol = 1e-5      # Minimum residual tolerance
L      = 128       # Grid size
T      = L*L       # Total number of basis functions 
res    = 50        # Upsampling/interpolation resolution when estimating period
pad    = 0.6       # Pad to avoid wrap-around from circular convolution; 0.5 = no padding
Fs     = 50.0      # Sample rate of data in Hz
Fl     = 0.25      # Low-frequency cutoff in Hz for smoothing path trajcetory for heading

# %% [markdown]
# # Find and load data

# %%
# 2D grid coordinates as complex numbers
coords = zgrid(L)
bins   = linspace(0,1,L+1,dtype='float32')

# Resolution for the camera used to record R1 is 350px/m;
# resolution for other rats (R11 and R18) was 338px/m
#px_p_meter = 338
#dataset    = 'R18_20200131_1to2_EC_good.mat'
#px_p_meter = 338
#dataset    = 'R11_20190607_1to2_EC_good.mat'
px_p_meter  = 350
dataset     = 'R1_20190823_2to1_EC_good.mat'
datasetname = dataset.split('_')[0]
dataset_ID  = re.match('(R\d+)_(\d+)',dataset).group(0)

# Load all datasets from this day
data = loadmat(datadir+dataset,squeeze_me=True)
xy50 = data['xy50'] # Position
sp50 = data['sp50'] # Spikes
hd50 = data['hd50'] # Head angle
ndatasets  = len(xy50)

# Which datasets to process? 
do_datasets = [1]#range(ndatasets)

# Rescale location data from all datasets using same transformation
allxy50 = np0.concatenate(xy50)
x,y     = allxy50.T
minx,maxx,miny,maxy = np.min(x),np.max(x),np.min(y),np.max(y)
delta   = np0.max([maxx-minx,maxy-miny])
scale   = (1-1e-6)/(delta*pad*2)

# Record grid scale
bins_p_meter = scale*L*px_p_meter
cm_p_bin     = 100/bins_p_meter
print('cm per bin',cm_p_bin)

# Load a given dataset, rescaling the spatial locations
def load_dataset(fn,dataindex):
    # Get dataset
    data = loadmat(fn,squeeze_me=True)
    xy50 = data['xy50'] # Position
    sp50 = data['sp50'] # Spikes
    hd50 = data['hd50'] # Head angle
    # Get specified dataset
    x,y  = xy50[dataindex].T
    s    = sp50[dataindex]
    x    = (x-(maxx+minx)/2+delta*pad)*scale
    y    = (y-(maxy+miny)/2+delta*pad)*scale
    return s,x,y,scale

def bin_spikes(x,y,s,bins,w=None):
    # Bin spike counts
    N    = histogram2d(y,x,(bins,bins),density=0,weights=w)[0]
    ws   = s if w is None else array(s)*array(w)
    K    = histogram2d(y,x,(bins,bins),density=0,weights=ws)[0]
    return N,K
# Out:
# cm per bin 3.1682123531314383

# %%
# Get specific dataset
idata = do_datasets[0]
s,x,y,scale = load_dataset(datadir+dataset,idata)

# Grab spikes
st    = find(s>0)
xs,ys = x[st],y[st]
sk    = s[st]
N,K   = bin_spikes(x,y,s,bins)
y1    = nan_to_num(K/N)
mask  = blur(N>0,2)>0.1

# Calibrate grid scale
λhat   = nan_to_num(K/N)
u      = outer(hanning(L),hanning(L))
acorr2 = fft_acorr(λhat*u,mask) # Get 2D autocorrelation
acorrR = radial_average(acorr2) # Get radial autocorrelation
res    = 50                     # Subsampling resolution
P,acup = acorr_peak(acorrR,res) # Distance to first peak in bins    

print('P=',P)
fgσ  = P/pi
bgσ  = fgσ*5
λhat = kdeλ(N,K,fgσ)
λbg  = kdeλ(N,K,bgσ)

# Precompute variables; Passed as globals to jac/hess
n    = N.ravel()               # Number of visits per bin
y    = nan_to_num(K/N).ravel() # Lumped pseudo-observerations
λhat = kdeλ(N,K,fgσ)           # KDE estimated rate
λbg  = kdeλ(N,K,bgσ)           # Background rate
lλh  = slog(λhat)              # Log rate
lλb  = slog(λbg)               # Log background
lλf  = lλh - lλb               # Foreground log rate

# Initial guess for kernel height
σ0   = zerolag(radial_acorr(lλf,mask))

figure(figsize=(5,4))
subplot(231)
showim(N,'Visits');
subplot(232)
showim(y1,'Activity');
subplot(233)
showim(mask,'Mask');
subplots_adjust(top=0.8)
suptitle('%s dataset %d'%(dataset,idata))
subplot(234)
showim(λhat,'KDE-smoothed rate');
subplot(235)
showim(lλf,'Foreground log-rate',mask=mask);
subplot(236)
showim(lλb,'Background log-rate',mask=mask);
tight_layout()
suptitle('%s dataset %d'%(dataset,idata))
# Out:
# P= 7.76
# Text(0.5, 0.98, 'R1_20190823_2to1_EC_good.mat dataset 1')

# %% [markdown]
# # Define hyperparameter search grid
#
# - β is the kernel height
# - P is the kernel period

# %%
rP   = 2
rβ   = 10
P_lo = P/rP
P_hi = P*rP
β_lo = 1/rβ
β_hi = 1*rβ
NP   = 11
Nβ   = 11
Ps   = float32(exp(linspace(log(P_lo),log(P_hi),NP)))
βs   = float32(exp(linspace(log(β_lo),log(β_hi),Nβ))[::-1])

@cache(NP*2)
def make_kernel_ft(L,P,σ0,dc=1e1,k=3):
    coords   = zgrid(L)
    window   = hanning(L)
    window   = fftshift(outer(window,window))
    kern     = j0(fftshift(abs(coords*2*pi/P)))*window
    clip     = fftshift(abs(coords)<P*jn_zeros(0,k)[-1]/(2*pi))
    kern     = kern*clip
    kern     = blur(kern,P/pi)
    kern     = repair_small_eigenvalues(kern*σ0/np.max(kern),1e-5)
    Kf       = np0.array(real(fft2(kern)))
    Kf[0,0] += dc
    return Kf

use2d = zeros((L,L),dtype='bool')
for p in Ps:
    Kf  = make_kernel_ft(L,p,σ0)
    thr = np.max(array(sorted(abs(Kf).ravel()))[:-1])/2
    use2d |= (abs(Kf))>thr

# Define low-rank Fourier space projection 
use2d   = use2d | use2d.T    # Ensure symmetric
use     = find(use2d.ravel()) # Indecies into LxL array to use4
R        = len(use)            # Number of components used
down     = eye(T)[use]         # Matrix to trim down a Fourier transform 

# Define low-rank cuts for 1D transform
use1d  = any(use2d,axis=0)                 # Indecies to use along L
f1De   = fft(eye(L),norm='ortho')[use1d,:] # 1D Fourier components used
f1De   = complex64(f1De)
R1d    = sum(use1d)                        # Number of components used in the 1D tranform
usecut = find(use2d[:,use1d][use1d,:])     # Subset of reduced 1Dx1D transform kept in full 2D transform

def reverse(A):
    # Exchange positive and negative frequencies in a 2D fourier transform
    return roll(roll(A[::-1,:],1,axis=0)[:,::-1],1,axis=1)

# Positive/negative frequency flip in reduced representation
hperm = int32(down@reverse((down.T@(arange(R))).reshape(L,L)).ravel())

def er(a,b): print(max(abs(a-b)))
def hcv(kh,xh):
    kh = kh/2
    kr,xr = kh[hperm],xh[hperm]
    return (kh+kr)*xh+(kh-kr)*xr
def hcm(kh,xh):
    kh = kh/2
    kr,xr = kh[hperm],xh[hperm]
    return (kh+kr)[:,None]*xh+(kh-kr)[:,None]*xr
def Ftv(v):  # Collapse vector DOWN
    return fhtv(v)[use]
def Fv(v):
    #return fhtv(zeros(T).at[use].set(v))
    x = zeros(T)
    x[use] = v
    return x
def fhtv(v):
    v = fft2(v.reshape(L,L),norm='ortho').ravel()
    return v.real+v.imag
def fhtA(x):
    x = fft2(x.reshape(x.shape[0],L,L),norm='ortho').reshape(x.shape[0],T)
    return x.real+x.imag
def FtA(A):  # Collapse matrix DOWN
    return fhtA(A.T).T[use,:]
def FA(A): 
    # Syntax for jax
    # return fhtA(zeros((T,A.shape[-1])).at[use,:].set(A).T).T
    X = zeros((T,A.shape[-1]))
    X[use,:] = A
    return fhtA(X.T).T
def dv(Q):
    return sum(FA(tril(Q))**2,1)
def chol(x):
    return numpy.linalg.cholesky(x)
def ltinv(ch):
    q,info = scipy.linalg.lapack.dtrtri(ch,lower=True)
    if info!=0: raise ValueError('lapack.dtrtri: '+(
            'argument %d invalid'%-info if info<0 
            else 'diagonal element %d is 0'%info))
    return q
def cv(K,v):
    return real(ifft2(fft2(v.reshape(L,L),norm='ortho')*K,norm='ortho')).ravel()
def cm(K,M):
    return real(ifft2(
        K[:,:,None]*fft2(M.reshape(L,L,M.shape[-1]),axes=(0,1)),
        axes=(0,1))).reshape(T,M.shape[-1])
def logdet(A):
    return sum(slog(diag(chol(A))))*2
    
# Precompute all manner of useful forms of a kernel
# TODO: check whether all of these are used
@cache(NP*2)
def prepare_kernel(p):
    Kf = make_kernel_ft(L,p,σ0)
    Λf = 1.0/Kf
    K0 = real(ifft2(Kf))
    Kh = (Kf.real+Kf.imag).ravel()[use]
    Λh = (Λf.real+Λf.imag).ravel()[use]
    sK = sum(log(Kf[use2d]))
    nK = sum(use2d)
    Λr = hcm(Λh,eye(R))
    K0,Kf,Λf,Kh,Λh,sK,nK,Λr = map(float32,[K0,Kf,Λf,Kh,Λh,sK,nK,Λr])
    return K0,Kf,Λf,Kh,Λh,sK,nK,Λr

K0,Kf,Λf,Kh,Λh,sK,nK,Λr = prepare_kernel(P)
subplot(131)
showkn(K0,'Kernel')
subplot(132)
showkn(Kf,'Fourier transform')
subplot(133)
showkn(use2d,'Coefficients used')

# %%
μ0 = float32(lλb.ravel())
μ  = float32(lλf.ravel())
nλ = float32(n*exp(μ+μ0))
n = float32(n)
y = float32(y)

def chinv(X):
    X = float32(X)
    X = scipy.linalg.cholesky(X,lower=True)
    X,info = scipy.linalg.lapack.dtrtri(X,lower=True)
    if info!=0: raise ValueError('lapack.dtrtri: '+(
            'argument %d invalid'%-info if info<0 
            else 'diagonal element %d is 0'%info))
    return X

def fast_low_rank_inverse_covariance(nλ,β,Λr):
    X  = sqrt(nλ.reshape(L,L),dtype='float32')
    X = (X[None,None,:,:]*f1De[:,None,:,None])*f1De[None,:,None,:]
    X  = X.real + X.imag
    X  = X.reshape(R1d*R1d,L*L)[usecut]
    return Λr*β + X@X.T

def fast_low_rank_covariance(nλ,β,Λr):
    Λp = fast_low_rank_inverse_covariance(nλ,β,Λr)
    A  = chinv(Λp)
    return A.T@A

def fast_inverse_diagonal(nλ,β,Λr):
    Λp = fast_low_rank_inverse_covariance(nλ,β,Λr)
    A  = chinv(Λp)
    X  = zeros((R,T),dtype='float32')
    X[:,use] = A
    A  = X.reshape(R,L,L)
    DF = fft2(A,norm='ortho')
    DF = DF.real + DF.imag
    DF = DF.reshape(R,T)
    v2 = sum(DF**2,0,dtype='float32')
    return v2

def loss(μ,v,β,p):
    '''
    n' [ λ - y∘μ ] + ½ μ' Λ₀ μ  + ½ ln|Σ₀| - ½ ln |Σ| + ½ tr[Λ₀ Σ]
    '''
    K0,Kf,Λf,Kh,Λh,sK,nK,Λr = prepare_kernel(p)
    nK = len(use)
    sK = sum(log(abs(Kf)))
    
    # We should work in low rank subspace
    μh   = Ftv(μ)
    μ    = Fv(μh)
    λ    = exp(μ + μ0 + v/2)
    nλ   = n*λ
    #lnΣ0 = sK-nK*log(β)
    lnΣ0 = -logdet(β*Λr)
    Σr   = fast_low_rank_covariance(nλ,β,Λr)
    return n@(λ-y*μ), μh@ hcv(β*Λh, μh)/2  , lnΣ0/2 , -logdet(Σr)/2 , trace(β*Λr@Σr)/2

def infer(μ,v,β,p,maxiter=100,showprogress=True):
    β = float64(β)
    p = float64(p)
    report = print if showprogress else lambda *x:()
    
    K0,Kf,Λf,Kh,Λh,sK,nK,Λr = prepare_kernel(p)
    
    # Prepare gradient and hessian operators
    M  = cop(Kf)
    Λ0 = cop(Λf)
    J  = lambda μ: β*Λ0@μ + n*(exp(μ+μ0)-y)
    H  = lambda μ: β*Λ0   + diagop(n*exp(μ+μ0))
    
    for j in range(maxiter):
        Δμ = -minres(H(μ),J(μ),tol=mintol,M=M)[0]
        μ += Δμ
        if max(abs(Δμ))<tol: break
        report('μ',max(abs(Δμ)),'initial')
    report('μ',max(abs(Δμ)),'initial')
    nλ = n*exp(μ + μ0)
    v  = fast_inverse_diagonal(nλ,β,Λr)
    assert v.dtype==np.float32
    report('(initialized)')
    
    for i in range(maxiter):
        vc = μ0+v/2
        J  = lambda μ: float64(β*Λ0@μ + n*(exp(μ+vc,dtype='float64')-y))
        for j in range(10):
            nλ = n*exp(μ+vc,dtype='float32')
            H  = op(T, lambda u: float64(β*Λ0@u + nλ*u))
            Δμ = -minres(H,J(μ),tol=mintol,M=M)[0]
            μ += Δμ
            if max(abs(Δμ))<tol: break
            report('μ',max(abs(Δμ)))
        nλ = n*exp(μ + μ0 + v/2)
        v2 = fast_inverse_diagonal(nλ,β,Λr)
        Δv = v2-v
        v += Δv
        report('Iteration',i)
        report('v',max(abs(Δv)))
        report('μ',max(abs(Δμ)))
        if max(abs(Δμ))<tol and max(abs(Δv))<tol: break
    tic('took')
    return μ,v,sum(array(loss(μ,v,β,p)))

# %%
#%load_ext snakeviz
#%snakeviz 

v = μ*0
β = 1
tic()
μ,v,l = infer(μ,v,β,P)
tic('took')
# Out:
# μ 21.849143617783422 initial
# μ 2.77053795363464 initial
# μ 0.9045914658081812 initial
# μ 0.36175407246357216 initial
# μ 0.05152337187920564 initial
# μ 0.0008317959788041901 initial
# μ 1.0680138493998367e-06 initial
# (initialized)
# μ 0.022505797757790616
# μ 0.00018131420126214884
# Iteration 0
# v 0.0005025342
# μ 1.1219770162455894e-06
# Iteration 1
# v 3.0845404e-06
# μ 8.929266565713615e-05
# Δt = 24282 ms elapsed for took
# Δt = 10245 ms elapsed for took
# 10245.95166015625

# %%
figure(dpi=600)
λ = exp(μ + μ0 + v/2)
subplot(131)
showim(μ.reshape(L,L),'Log-rate\n(above background)',mask=mask)
subplot(132)
showim(λ.reshape(L,L),'Mean rate',mask=mask)
subplot(133)
showim(1/v.reshape(L,L),'Confidence',mask=mask)
suptitle('Initial estimate based on heuristic period, variance')
# Out:
# Text(0.5, 0.98, 'Initial estimate based on heuristic period, variance')

# %% [markdown]
# # Double check Hartley transform
#
# - Kernels are Hermitian; Hartley transform is the Fourier transform

# %%
K0,Kf,Λf,Kh,Λh,sK,nK,Λr = prepare_kernel(p)

x  = randn(L,L)
xf = fft2(x,norm='ortho')[use2d].ravel()
xh = xf.real + xf.imag
ch = xh*Kh
c  = zeros((L,L))
c[use2d] = ch
c  = fft2(c,norm='ortho')
c  = c.real + c.imag

subplot(121)
imshow(c.reshape(L,L))
axis('off')
colorbar()
subplot(122)

#c2 = ifft2(Kf*fft2(x)).real

xf = fft2(x)[use2d]
ch = xf*fft2(K0)[use2d]
c2 = zeros((L,L))
c2[use2d] = ch
c2 = ifft2(c2).real

f1 = fft2(x)[use2d]
f2 = fft2(K0)[use2d].real
f3 = f1*f2
c2 = zeros((L,L),dtype='complex64')
c2[use2d] = f3
c2 = ifft2(c2).real

imshow(c2)
axis('off')
colorbar()

print(np.max(abs(c-c2)))
# Out:
# /home/cfs/mer49/.local/lib/python3.6/site-packages/ipykernel_launcher.py:23: ComplexWarning: Casting complex values to real discards the imaginary part
# 1.5078711310678727e-06

# %% [markdown]
# # Check Choleskey inverse

# %%
def chinv(X):
    '''
    Q  = float64(randn(100,100))
    Q  = Q@Q.T
    i1 = inv(Q)
    i2 = chinv(Q)
    i2 = i2.T@i2
    np.max(abs(i1-i2))
    '''
    X = float64(X)
    X = scipy.linalg.cholesky(X,lower=True)
    X,info = scipy.linalg.lapack.dtrtri(X,lower=True)
    if info!=0: raise ValueError('lapack.dtrtri: '+(
            'argument %d invalid'%-info if info<0 
            else 'diagonal element %d is 0'%info))
    return X

Q  = float64(randn(100,100))
Q  = Q@Q.T
i1 = inv(Q)
i2 = chinv(Q)
i2 = i2.T@i2
np.max(abs(i1-i2))
# Out:
# 2.900719664467033e-10

# %% [markdown]
# # Separable Hartley

# %%
x = randn(3,3)

# FFT is separable
a = fft(x,axis=0,norm='ortho')
b = fft(a,axis=1,norm='ortho')
c = fft2(x,norm='ortho')
print(allclose(b,c))

# FHT is not
h = c.real + c.imag
a = fft(x,axis=0,norm='ortho')
a = a.real + a.imag
b = fft(a,axis=1,norm='ortho')
b = b.real + b.imag
print(allclose(b,h))

# FFT is separable
a = fft(x,axis=0,norm='ortho')
a1 = array(a)
a = a.real + a.imag
ar = roll(a[::-1,:],1,axis=0)
a = ((a + ar) + 1j*(a - ar))/2
print(allclose(a,a1))
b = fft(a,axis=1,norm='ortho')
#b1 = array(b)
#b = b.real + b.imag
#br = roll(b[:,::-1],1,axis=1)
#b = ((b + br) + 1j*(b - br))/2
#print(allclose(b,b1))
c = fft2(x,norm='ortho')
print(allclose(b,c))

#b = fft(a,axis=1,norm='ortho')
#b = b.real + b.imag
#c = fft2(x,norm='ortho')
#print(allclose(b,c))7

def reverse(A):
    # Exchange positive and negative frequencies in a 2D fourier transform
    return roll(roll(A[::-1,:],1,axis=0)[:,::-1],1,axis=1)
print(allclose(c,conj(reverse(c))))
print(np.max(abs(c - conj(reverse(c)))))
# Out:
# True
# False
# True
# True
# True
# 0.0

# %% [markdown]
# # Check that low-rank inverse is correct
#
# We can't actually compute this easily.

# %%
# Streamline precomputation of low-rank collapse of diagonal matrix
f1e = fft(eye(L),norm='ortho')[use1d,:]
f2e = f1e[:,None,:,None]*f1e[None,:,None,:]
h2e = f2e.real + f2e.imag
h2e = h2e.reshape(R1d*R1d,L*L)[usecut]

λ   = exp(μ + μ0 + v/2)
nλ  = n*λ
x   = sqrt(nλ)
x   = x[None,:]*h2e
xxt = x@x.T

'''
Check that this agrees with other ways of comput F𝔻[nλ]F'
(it does)
other = FtA(FtA(diag(nλ)).T).T
print(np.max(abs(other-xxt)))
q = FtA(diag(sqrt(nλ)))
qqt = q@q.T
print(np.max(abs(qqt-xxt)))
'''

'''
Sanity check the prior kernel
print(np.max(abs(hcm(Λh,eye(R))-diag(Λh))))
'''

Λp  = β*diag(Λh) + xxt
Cp  = chinv(Λp)
Σp  = Cp.T @ Cp

'''
Sanity check Choleskey inverse
print(allclose(eye(R),Σp@Λp))
'''

def fast_low_rank_covariance(nλ,β,Λr):
    λ   = exp(μ + μ0 + v/2)
    nλ  = n*λ
    x   = sqrt(nλ)
    x   = x[None,:]*h2e
    xxt = x@x.T
    Λp  = β*diag(Λh) + xxt
    Cp  = chinv(Λp)
    Σp  = Cp.T @ Cp
    return Σp
    
def fast_covariance_diagonal(nλ,β,Λr):
    λ   = exp(μ + μ0 + v/2)
    nλ  = n*λ
    x   = sqrt(nλ)
    x   = x[None,:]*h2e

# %%
shape(x)

# %%
def fast_low_rank_inverse_covariance(nλ,β,Λr):
    X  = sqrt(nλ.reshape(L,L),dtype='float32')
    X  = X.real + X.imag
    X  = X.reshape(R1d*R1d,L*L)[usecut]
    return Λr*β + X@X.T

def fast_low_rank_covariance(nλ,β,Λr):
    Λp = fast_low_rank_inverse_covariance(nλ,β,Λr)
    A  = chinv(Λp)
    return A.T@A

def fast_inverse_diagonal(nλ,β,Λr):
    Λp = fast_low_rank_inverse_covariance(nλ,β,Λr)
    A  = chinv(Λp)
    X  = zeros((R,T),dtype='float32')
    X[:,use] = A
    A  = X.reshape(R,L,L)
    DF = fft2(A,norm='ortho')
    DF = DF.real + DF.imag
    DF = DF.reshape(R,T)
    v2 = sum(DF**2,0,dtype='float32')
    return v2

# %% [markdown]
# # Double check that loss is correct

# %%
def loss(μ,v,β,p):
    '''
    n' [ λ - y∘μ ] + ½ μ' Λ₀ μ  + ½ ln|Σ₀| - ½ ln |Σ| + ½ tr[Λ₀ Σ]
    '''
    K0,Kf,Λf,Kh,Λh,sK,nK,Λr = prepare_kernel(p)
    
    λ    = exp(μ + μ0 + v/2)
    nλ   = n*λ
    
    Σr   = fast_low_rank_covariance(nλ,β,Λr)
    return n@(λ-y*μ), μh@ hcv(β*Λh, μh)/2  , -logdet(β*Λr)/2 , -logdet(Σr)/2 , trace(β*Λr@Σr)/2

# %%
def loss(μ,v,β,p):
    '''
    n' [ λ - y∘μ ] + ½ μ' Λ₀ μ  + ½ ln|Σ₀| - ½ ln |Σ| + ½ tr[Λ₀ Σ]
    '''
    K0,Kf,Λf,Kh,Λh,sK,nK,Λr = prepare_kernel(p)
    
    # We should work in low rank subspace
    μh   = Ftv(μ)
    μ    = Fv(μh)
    λ    = exp(μ + μ0 + v/2)
    nλ   = n*λ
    Σr   = fast_low_rank_covariance(nλ,β,Λr)
    return n@(λ-y*μ), μh@ hcv(β*Λh, μh)/2  , -logdet(β*Λr)/2 , -logdet(Σr)/2 , trace(β*Λr@Σr)/2

# %%
assert 0

# %%
K0,Kf,Λf,Kh,Λh,sK,nK,Λr = prepare_kernel(p)

# %%
figure(dpi=600)
imshow(abs(Λr)>0)

# %%
shape(Λr)
# Out:
# (3029, 3029)

# %%
R
# Out:
# 3029

# %%
from IPython.display import clear_output

ip = NP//2
iβ = Nβ//2
p  = Ps[ip]
β  = βs[iβ]

μ,v,l = infer(μ,v,float(β),float(p))
print('\tβ[%d] ='%iβ,β,'\tloss = ',l)
μref,vref = μ,v

results = np0.empty((NP,Nβ),dtype='object')
def current_best():
    global results
    losses  = array([inf if r is None else r[2] for r in results.ravel()])
    bestidx = argmin(losses)
    bestP,bestβ = unravel_index(bestidx,results.shape)
    return bestP, bestβ, losses[bestidx]  
def search(ip,iβ):
    global results
    print('P[%d]=%0.2f β[%d]=%0.2f'%(ip,Ps[ip],iβ,βs[iβ]))
    
    # Return if out of bounds; Return memoized if possible; 
    if iβ<0 or ip<0 or iβ>=Nβ or ip>=NP: return
    if results[ip,iβ]: return

    # Get initial conditions via extrapolation when possible
    if iβ+2<Nβ and results[ip,iβ+1] and results[ip,iβ+2]:
        (μ1,v1),(μ2,v2) = results[ip,iβ+1][:2], results[ip,iβ+2][:2]
        μ = 2*μ1 - μ2
        v = 2*v1 - v2
    elif iβ>=2 and results[ip,iβ-1] and results[ip,iβ-2]:
        (μ1,v1),(μ2,v2) = results[ip,iβ-1][:2], results[ip,iβ-2][:2]
        μ = 2*μ1 - μ2
        v = 2*v1 - v2
    elif iβ+1<Nβ and results[ip,iβ+1]: μ,v = results[ip,iβ+1][:2]
    elif iβ>=1   and results[ip,iβ-1]: μ,v = results[ip,iβ-1][:2]
    elif ip+1<NP and results[ip+1,iβ]: μ,v = results[ip+1,iβ][:2]
    elif ip>=1   and results[ip-1,iβ]: μ,v = results[ip-1,iβ][:2]
    else: μ,v = μref,vref
    
    β = βs[iβ]
    μ,v,l = infer(μ,v,float(β),float(p))
    results[ip,iβ] = (μ,v,l)
    print('P[%d]=%0.2f β[%d]=%0.2f loss=%f'%(ip,Ps[ip],iβ,βs[iβ],l))
    clear_output(wait=True)
    figure()
    imshow(array([r[2] if not r is None else nan for r in results.ravel()]).reshape(NP,Nβ))
    show()
    for Δp,Δβ in [(0,1),(0,-1),(1,0),(-1,0)]:
        if current_best()[:2]!=(ip,iβ): break
        search(ip+Δp,iβ+Δβ)
    return

ip = NP//2
iβ = Nβ//2
import cProfile
cProfile.run('search(ip,iβ);')
# Out:
#          1522118 function calls (1490462 primitive calls) in 142.992 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#        22    0.000    0.000    0.001    0.000 1677864242.py:13(current_best)
#        22    0.000    0.000    0.000    0.000 1677864242.py:15(<listcomp>)
#      15/1    0.003    0.000  142.992  142.992 1677864242.py:19(search)
#         9    0.000    0.000    0.000    0.000 1677864242.py:48(<listcomp>)
#        30   80.126    2.671   80.126    2.671 3948571759.py:16(fast_low_rank_inverse_covariance)
#         9    1.840    0.204   27.655    3.073 3948571759.py:23(fast_low_rank_covariance)
#        21   10.711    0.510   99.063    4.717 3948571759.py:28(fast_inverse_diagonal)
#         9    2.713    0.301   33.194    3.688 3948571759.py:40(loss)
#         9    0.264    0.029  141.225   15.692 3948571759.py:58(infer)
#        25    0.009    0.000    0.067    0.003 3948571759.py:68(<lambda>)
#        25    0.011    0.000    0.017    0.001 3948571759.py:69(<lambda>)
#        30    2.894    0.096    5.572    0.186 3948571759.py:7(chinv)
#        22    0.028    0.001    0.074    0.003 3948571759.py:84(<lambda>)
#       356    0.099    0.000    1.457    0.004 3948571759.py:87(<lambda>)
#         9    0.001    0.000    0.001    0.000 4971050.py:53(hcv)
#         9    0.000    0.000    0.005    0.001 4971050.py:61(Ftv)
#         9    0.000    0.000    0.000    0.000 4971050.py:63(Fv)
#         9    0.001    0.000    0.005    0.001 4971050.py:68(fhtv)
#        18    0.000    0.000    2.812    0.156 4971050.py:84(chol)
#        18    0.001    0.000    2.817    0.157 4971050.py:98(logdet)
#       873    0.001    0.000    0.010    0.000 <__array_function__ internals>:2(all)
#      4401    0.002    0.000    0.026    0.000 <__array_function__ internals>:2(amax)
#      4356    0.003    0.000    0.029    0.000 <__array_function__ internals>:2(amin)
#       216    0.000    0.000    0.007    0.000 <__array_function__ internals>:2(any)
#        22    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(argmin)
#      1080    0.001    0.000    0.009    0.000 <__array_function__ internals>:2(around)
#        30    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(atleast_2d)
#       378    0.001    0.000    0.008    0.000 <__array_function__ internals>:2(broadcast_arrays)
#         9    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(can_cast)
#        18    0.000    0.000    2.812    0.156 <__array_function__ internals>:2(cholesky)
#       398    0.001    0.000    0.019    0.000 <__array_function__ internals>:2(clip)
#       396    0.001    0.000    0.010    0.000 <__array_function__ internals>:2(column_stack)
#       567    0.001    0.000    0.005    0.000 <__array_function__ internals>:2(concatenate)
#        54    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(copyto)
#        18    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(cumsum)
#        18    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(diag)
#        18    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(diagonal)
#       216    0.000    0.000    0.006    0.000 <__array_function__ internals>:2(diff)
#      5088    0.006    0.000    0.227    0.000 <__array_function__ internals>:2(dot)
#        27    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(in1d)
#      1459    0.005    0.000    0.516    0.000 <__array_function__ internals>:2(inner)
#        27    0.000    0.000    0.002    0.000 <__array_function__ internals>:2(intersect1d)
#         9    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(inv)
#        27    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(isin)
#        54    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(min_scalar_type)
#      2877    0.003    0.000    0.013    0.000 <__array_function__ internals>:2(ndim)
#       378    0.000    0.000    0.002    0.000 <__array_function__ internals>:2(nonzero)
#      2118    0.004    0.000    0.264    0.000 <__array_function__ internals>:2(norm)
#        18    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(prod)
#       360    0.000    0.000    0.005    0.000 <__array_function__ internals>:2(ptp)
#      1179    0.001    0.000    0.018    0.000 <__array_function__ internals>:2(reshape)
#      1080    0.001    0.000    0.012    0.000 <__array_function__ internals>:2(round_)
#        57    0.000    0.000    1.311    0.023 <__array_function__ internals>:2(sum)
#         9    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(trace)
#        54    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(unique)
#        31    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(unravel_index)
#        18    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(where)
#        90    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1017(_handle_fromlist)
#       225    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:389(parent)
#         1    0.000    0.000  142.992  142.992 <string>:1(<module>)
#      1134    0.001    0.000    0.002    0.000 <string>:1(__new__)
#         9    0.000    0.000    0.039    0.004 Image.py:2158(save)
#        18    0.000    0.000    0.000    0.000 Image.py:2651(_check_size)
#         9    0.000    0.000    0.000    0.000 Image.py:2669(new)
#         9    0.000    0.000    0.000    0.000 Image.py:2746(frombuffer)
#         9    0.000    0.000    0.000    0.000 Image.py:341(preinit)
#         9    0.000    0.000    0.000    0.000 Image.py:436(_getencoder)
#        27    0.000    0.000    0.000    0.000 Image.py:524(__init__)
#        36    0.000    0.000    0.000    0.000 Image.py:556(size)
#        18    0.000    0.000    0.000    0.000 Image.py:560(_new)
#         9    0.000    0.000    0.001    0.000 Image.py:616(_copy)
#         9    0.000    0.000    0.001    0.000 Image.py:622(_ensure_mutable)
#        18    0.000    0.000    0.000    0.000 Image.py:814(load)
#         9    0.000    0.000    0.038    0.004 ImageFile.py:478(_save)
#         9    0.000    0.000    0.000    0.000 ImageFile.py:79(_tilesort)
#        45    0.000    0.000    0.000    0.000 PngImagePlugin.py:1025(putchunk)
#         9    0.000    0.000    0.000    0.000 PngImagePlugin.py:1039(__init__)
#         9    0.000    0.000    0.000    0.000 PngImagePlugin.py:1043(write)
#         9    0.000    0.000    0.038    0.004 PngImagePlugin.py:1191(_save)
#        90    0.000    0.000    0.000    0.000 PngImagePlugin.py:137(_crc32)
#         9    0.000    0.000    0.000    0.000 PngImagePlugin.py:265(__init__)
#         9    0.000    0.000    0.000    0.000 PngImagePlugin.py:268(add)
#         9    0.000    0.000    0.000    0.000 PngImagePlugin.py:311(add_text)
#      8802    0.009    0.000    0.011    0.000 __init__.py:101(check_in_list)
#        72    0.000    0.000    0.000    0.000 __init__.py:106(__init__)
#         9    0.000    0.000    0.000    0.000 __init__.py:109(__call__)
#       153    0.000    0.000    0.000    0.000 __init__.py:115(__hash__)
#         9    0.000    0.000    0.000    0.000 __init__.py:1180(is_interactive)
#        90    0.000    0.000    0.001    0.000 __init__.py:119(_weak_or_strong_ref)
#       918    0.002    0.000    0.003    0.000 __init__.py:1277(is_math_text)
#      1998    0.003    0.000    0.008    0.000 __init__.py:1290(_to_unmasked_float_array)
#       648    0.003    0.000    0.005    0.000 __init__.py:132(check_shape)
#         9    0.000    0.000    0.018    0.002 __init__.py:1409(inner)
#      1998    0.001    0.000    0.001    0.000 __init__.py:1424(debug)
#      1944    0.001    0.000    0.001    0.000 __init__.py:152(<genexpr>)
#       378    0.000    0.000    0.000    0.000 __init__.py:1619(<lambda>)
#        72    0.000    0.000    0.001    0.000 __init__.py:1661(safe_first_element)
#         9    0.000    0.000    0.000    0.000 __init__.py:1683(sanitize_sequence)
#      1998    0.000    0.000    0.000    0.000 __init__.py:1689(isEnabledFor)
#      3402    0.027    0.000    0.045    0.000 __init__.py:1691(normalize_kwargs)
#       144    0.000    0.000    0.000    0.000 __init__.py:171(check_getitem)
#      3402    0.012    0.000    0.012    0.000 __init__.py:1730(<dictcomp>)
#      3085    0.001    0.000    0.002    0.000 __init__.py:1799(_str_equal)
#       441    0.000    0.000    0.001    0.000 __init__.py:1810(_str_lower_equal)
#        72    0.000    0.000    0.002    0.000 __init__.py:183(dumps)
#      1341    0.004    0.000    0.004    0.000 __init__.py:184(__init__)
#      8820    0.104    0.000    0.113    0.000 __init__.py:2014(_setattr_cm)
#         9    0.000    0.000    0.000    0.000 __init__.py:2059(__init__)
#         9    0.000    0.000    0.000    0.000 __init__.py:2071(add)
#        90    0.001    0.000    0.002    0.000 __init__.py:214(connect)
#         9    0.000    0.000    0.000    0.000 __init__.py:232(_remove_proxy)
#         9    0.000    0.000    0.000    0.000 __init__.py:250(disconnect)
#       144    0.000    0.000    0.000    0.000 __init__.py:269(wrapper)
# 6813/6795    0.013    0.000    0.017    0.000 __init__.py:276(process)
#        36    0.000    0.000    0.000    0.000 __init__.py:296(blocked)
#       144    0.001    0.000    0.009    0.000 __init__.py:512(_get_data_path)
#       216    0.002    0.000    0.002    0.000 __init__.py:557(__setitem__)
#        18    0.000    0.000    0.000    0.000 __init__.py:570(__init__)
#        27    0.000    0.000    0.000    0.000 __init__.py:598(push)
#        18    0.000    0.000    0.000    0.000 __init__.py:619(empty)
#        36    0.000    0.000    0.000    0.000 __init__.py:623(clear)
#         9    0.000    0.000    0.000    0.000 __init__.py:628(bubble)
#      1656    0.005    0.000    0.007    0.000 __init__.py:65(check_isinstance)
#     44890    0.032    0.000    0.044    0.000 __init__.py:653(__getitem__)
#         9    0.000    0.000    0.001    0.000 __init__.py:700(safe_masked_invalid)
#         9    0.000    0.000    0.000    0.000 __init__.py:73(get_projection_class)
#      1764    0.000    0.000    0.000    0.000 __init__.py:80(<genexpr>)
#        18    0.000    0.000    0.000    0.000 __init__.py:817(__init__)
#        18    0.000    0.000    0.000    0.000 __init__.py:818(<dictcomp>)
#        45    0.000    0.000    0.000    0.000 __init__.py:820(__contains__)
#      3852    0.003    0.000    0.004    0.000 __init__.py:823(clean)
#      3852    0.001    0.000    0.001    0.000 __init__.py:826(<listcomp>)
#      3834    0.007    0.000    0.014    0.000 __init__.py:872(get_siblings)
#      3834    0.002    0.000    0.002    0.000 __init__.py:876(<listcomp>)
#         9    0.000    0.000    0.000    0.000 __init__.py:98(get_projection_class)
#      8233    0.006    0.000    0.018    0.000 _asarray.py:110(asanyarray)
#     17334    0.012    0.000    0.058    0.000 _asarray.py:23(asarray)
#         9    0.002    0.000    0.018    0.002 _axes.py:5233(imshow)
#      3136    0.011    0.000   31.841    0.010 _backend.py:17(__ua_function__)
#     54/45    0.000    0.000    0.003    0.000 _base.py:1003(get_position)
#        54    0.000    0.000    0.007    0.000 _base.py:1055(_set_position)
#        18    0.000    0.000    0.000    0.000 _base.py:1082(set_axes_locator)
#        72    0.000    0.000    0.000    0.000 _base.py:1093(get_axes_locator)
#        36    0.000    0.000    0.001    0.000 _base.py:1099(_set_artist_props)
#         9    0.000    0.000    0.003    0.000 _base.py:1109(_gen_axes_patch)
#         9    0.000    0.000    0.017    0.002 _base.py:1126(_gen_axes_spines)
#        45    0.000    0.000    0.017    0.000 _base.py:1141(<genexpr>)
#         9    0.001    0.000    0.332    0.037 _base.py:1182(cla)
#         9    0.000    0.000    0.001    0.000 _base.py:1493(_set_title_offset_trans)
#        45    0.000    0.000    0.000    0.000 _base.py:1579(get_aspect)
#         9    0.000    0.000    0.000    0.000 _base.py:1587(set_aspect)
#         9    0.000    0.000    0.000    0.000 _base.py:1671(set_adjustable)
#         9    0.000    0.000    0.000    0.000 _base.py:1735(set_box_aspect)
#        45    0.000    0.000    0.000    0.000 _base.py:1772(get_anchor)
#        45    0.001    0.000    0.004    0.000 _base.py:1833(get_data_ratio)
#        45    0.001    0.000    0.016    0.000 _base.py:1847(apply_aspect)
#         9    0.000    0.000    0.000    0.000 _base.py:2135(_sci)
#         9    0.000    0.000    0.000    0.000 _base.py:2170(_deprecate_noninstance)
#        18    0.000    0.000    0.000    0.000 _base.py:223(__init__)
#         9    0.000    0.000    0.001    0.000 _base.py:2257(add_image)
#        18    0.000    0.000    0.000    0.000 _base.py:236(set_prop_cycle)
#        18    0.000    0.000    0.000    0.000 _base.py:2417(_unit_change_handler)
#         9    0.000    0.000    0.001    0.000 _base.py:2457(update_datalim)
#        36    0.000    0.000    0.002    0.000 _base.py:2482(_process_unit_info)
#        36    0.000    0.000    0.000    0.000 _base.py:2539(<listcomp>)
#       207    0.001    0.000    0.001    0.000 _base.py:2939(_get_axis_list)
#       621    0.000    0.000    0.001    0.000 _base.py:2940(<genexpr>)
#       135    0.000    0.000    0.002    0.000 _base.py:2942(_get_axis_map)
#        36    0.001    0.000    0.020    0.001 _base.py:2955(_update_title_position)
#       144    0.000    0.000    0.000    0.000 _base.py:3006(<genexpr>)
#        18    0.000    0.000    0.526    0.029 _base.py:3013(draw)
#         9    0.000    0.000    0.001    0.000 _base.py:3150(set_axisbelow)
#        18    0.000    0.000    0.199    0.011 _base.py:3186(grid)
#        18    0.000    0.000    0.013    0.001 _base.py:3349(tick_params)
#         9    0.000    0.000    0.000    0.000 _base.py:3437(set_axis_on)
#        45    0.000    0.000    0.001    0.000 _base.py:3516(get_xbound)
#        45    0.000    0.000    0.001    0.000 _base.py:3564(get_xlim)
#        72    0.001    0.000    0.002    0.000 _base.py:3587(_validate_converted_limits)
#        18    0.001    0.000    0.004    0.000 _base.py:3604(set_xlim)
#        45    0.000    0.000    0.001    0.000 _base.py:3860(get_ybound)
#        45    0.000    0.000    0.001    0.000 _base.py:3908(get_ylim)
#        18    0.000    0.000    0.003    0.000 _base.py:3931(set_ylim)
#         9    0.000    0.000    0.000    0.000 _base.py:4198(set_navigate)
#         9    0.000    0.000    0.000    0.000 _base.py:4214(set_navigate_mode)
#        63    0.001    0.000    0.002    0.000 _base.py:4500(get_children)
#        27    0.000    0.000    0.001    0.000 _base.py:4526(get_default_bbox_extra_artists)
#        27    0.000    0.000    0.000    0.000 _base.py:4550(<listcomp>)
#        18    0.001    0.000    0.229    0.013 _base.py:4553(get_tightbbox)
#        18    0.000    0.000    0.000    0.000 _base.py:4664(<listcomp>)
#         9    0.001    0.000    0.435    0.048 _base.py:553(__init__)
#         9    0.000    0.000    0.000    0.000 _base.py:611(<dictcomp>)
#       126    0.000    0.000    0.000    0.000 _base.py:724(get_window_extent)
#        36    0.000    0.000    0.000    0.000 _base.py:74(wrapper)
#         9    0.000    0.000    0.064    0.007 _base.py:741(_init_axis)
#         9    0.000    0.000    0.004    0.000 _base.py:751(set_figure)
#      1746    0.003    0.000    0.025    0.000 _base.py:765(_unstale_viewLim)
#      1746    0.005    0.000    0.021    0.000 _base.py:768(<dictcomp>)
#      6984    0.002    0.000    0.002    0.000 _base.py:769(<genexpr>)
#      1728    0.002    0.000    0.027    0.000 _base.py:779(viewLim)
#         9    0.000    0.000    0.003    0.000 _base.py:803(_set_lim_and_transforms)
#   747/405    0.002    0.000    0.006    0.000 _base.py:839(get_xaxis_transform)
#        81    0.001    0.000    0.005    0.000 _base.py:863(get_xaxis_text1_transform)
#        81    0.001    0.000    0.004    0.000 _base.py:889(get_xaxis_text2_transform)
#   747/405    0.002    0.000    0.006    0.000 _base.py:915(get_yaxis_transform)
#        81    0.001    0.000    0.004    0.000 _base.py:939(get_yaxis_text1_transform)
#        81    0.001    0.000    0.004    0.000 _base.py:965(get_yaxis_text2_transform)
#        18    0.000    0.000    0.002    0.000 _base.py:991(_update_transScale)
#       126    0.000    0.000    0.000    0.000 _binary.py:101(o32be)
#         9    0.000    0.000    0.000    0.000 _collections_abc.py:676(items)
#        63    0.000    0.000    0.000    0.000 _collections_abc.py:680(values)
#        72    0.000    0.000    0.000    0.000 _collections_abc.py:698(__init__)
#        63    0.000    0.000    0.000    0.000 _collections_abc.py:701(__len__)
#        45    0.000    0.000    0.000    0.000 _collections_abc.py:742(__iter__)
#       315    0.000    0.000    0.001    0.000 _collections_abc.py:760(__iter__)
#       796    0.001    0.000    0.001    0.000 _methods.py:100(_clip_dep_is_byte_swapped)
#       398    0.004    0.000    0.004    0.000 _methods.py:105(_clip_dep_invoke_with_casting)
#       398    0.002    0.000    0.014    0.000 _methods.py:124(_clip)
#       360    0.002    0.000    0.003    0.000 _methods.py:273(_ptp)
#      2502    0.001    0.000    0.009    0.000 _methods.py:37(_amax)
#      1062    0.001    0.000    0.007    0.000 _methods.py:41(_amin)
#       378    0.000    0.000    0.003    0.000 _methods.py:45(_sum)
#        90    0.000    0.000    0.001    0.000 _methods.py:53(_any)
#       102    0.000    0.000    0.030    0.000 _methods.py:59(_all)
#       796    0.004    0.000    0.007    0.000 _methods.py:90(_clip_dep_is_scalar_nan)
#        27    0.000    0.000    0.000    0.000 _pylab_helpers.py:105(get_active)
#         9    0.000    0.000    0.000    0.000 _pylab_helpers.py:110(_set_new_active_manager)
#         9    0.000    0.000    0.000    0.000 _pylab_helpers.py:123(set_active)
#         9    0.000    0.000    0.000    0.000 _pylab_helpers.py:34(get_fig_manager)
#         9    0.000    0.000    0.004    0.000 _pylab_helpers.py:78(destroy_all)
#        18    0.000    0.000    0.000    0.000 _pylab_helpers.py:95(get_all_fig_managers)
#         9    0.000    0.000    0.443    0.049 _subplots.py:14(__init__)
#         9    0.000    0.000    0.007    0.001 _subplots.py:58(set_subplotspec)
#        36    0.000    0.000    0.000    0.000 _ufunc_config.py:132(geterr)
#        36    0.000    0.000    0.000    0.000 _ufunc_config.py:32(seterr)
#        18    0.000    0.000    0.000    0.000 _ufunc_config.py:429(__init__)
#        18    0.000    0.000    0.000    0.000 _ufunc_config.py:433(__enter__)
#        18    0.000    0.000    0.000    0.000 _ufunc_config.py:438(__exit__)
#         9    0.000    0.000    0.000    0.000 _util.py:5(isPath)
#       279    0.000    0.000    0.000    0.000 abc.py:100(__subclasscheck__)
#     11059    0.006    0.000    0.017    0.000 abc.py:96(__instancecheck__)
#        54    0.000    0.000    0.000    0.000 arraysetops.py:125(_unpack_tuple)
#        54    0.000    0.000    0.000    0.000 arraysetops.py:133(_unique_dispatcher)
#        54    0.000    0.000    0.001    0.000 arraysetops.py:138(unique)
#        54    0.001    0.000    0.001    0.000 arraysetops.py:310(_unique1d)
#        27    0.000    0.000    0.000    0.000 arraysetops.py:343(_intersect1d_dispatcher)
#        27    0.000    0.000    0.001    0.000 arraysetops.py:348(intersect1d)
#        27    0.000    0.000    0.000    0.000 arraysetops.py:494(_in1d_dispatcher)
#        27    0.000    0.000    0.001    0.000 arraysetops.py:498(in1d)
#        27    0.000    0.000    0.000    0.000 arraysetops.py:611(_isin_dispatcher)
#        27    0.000    0.000    0.001    0.000 arraysetops.py:615(isin)
#      1179    0.002    0.000    0.007    0.000 artist.py:1001(set_visible)
#         9    0.000    0.000    0.000    0.000 artist.py:1033(set_in_layout)
#      2871    0.029    0.000    0.200    0.000 artist.py:1046(update)
#        18    0.000    0.000    0.000    0.000 artist.py:1072(get_label)
#        18    0.000    0.000    0.000    0.000 artist.py:1076(set_label)
#        18    0.000    0.000    0.000    0.000 artist.py:1092(get_zorder)
#       378    0.001    0.000    0.003    0.000 artist.py:1096(set_zorder)
#      2178    0.001    0.000    0.001    0.000 artist.py:1111(sticky_edges)
#       540    0.004    0.000    0.008    0.000 artist.py:1138(update_from)
#      1971    0.004    0.000    0.200    0.000 artist.py:1159(set)
#      1971    0.003    0.000    0.203    0.000 artist.py:116(<lambda>)
#       486    0.001    0.000    0.024    0.000 artist.py:1166(_cm_set)
#       243    0.000    0.000    0.001    0.000 artist.py:1171(<dictcomp>)
#        36    0.000    0.000    0.000    0.000 artist.py:1298(mouseover)
#      1134    0.017    0.000    0.026    0.000 artist.py:149(__init__)
#      3654    0.002    0.000    0.006    0.000 artist.py:242(convert_xunits)
#      3654    0.001    0.000    0.004    0.000 artist.py:254(convert_yunits)
#     24381    0.004    0.000    0.004    0.000 artist.py:266(axes)
#      1395    0.001    0.000    0.001    0.000 artist.py:271(axes)
# 47745/36279    0.034    0.000    0.054    0.000 artist.py:290(stale)
#   1692/18    0.005    0.000    0.540    0.030 artist.py:32(draw_wrapper)
#       144    0.000    0.000    0.000    0.000 artist.py:323(_get_clipping_extent_bbox)
#       144    0.000    0.000    0.037    0.000 artist.py:340(get_tightbbox)
#      6714    0.007    0.000    0.023    0.000 artist.py:405(pchanged)
#        36    0.000    0.000    0.000    0.000 artist.py:418(is_transform_set)
#       972    0.002    0.000    0.006    0.000 artist.py:426(set_transform)
#      2286    0.001    0.000    0.002    0.000 artist.py:439(get_transform)
#       234    0.000    0.000    0.000    0.000 artist.py:590(get_url)
#         9    0.000    0.000    0.000    0.000 artist.py:594(set_url)
#       846    0.000    0.000    0.000    0.000 artist.py:604(get_gid)
#       108    0.000    0.000    0.000    0.000 artist.py:618(get_snap)
#       324    0.000    0.000    0.000    0.000 artist.py:657(get_sketch_params)
#        18    0.000    0.000    0.540    0.030 artist.py:71(draw_wrapper)
#       540    0.000    0.000    0.000    0.000 artist.py:716(get_path_effects)
#        45    0.000    0.000    0.000    0.000 artist.py:719(get_figure)
#      1125    0.002    0.000    0.007    0.000 artist.py:723(set_figure)
#        27    0.000    0.000    0.000    0.000 artist.py:747(set_clip_box)
#       135    0.003    0.000    0.036    0.000 artist.py:759(set_clip_path)
#      6345    0.006    0.000    0.019    0.000 artist.py:81(_stale_axes_callback)
#       234    0.000    0.000    0.000    0.000 artist.py:821(get_alpha)
#      7038    0.001    0.000    0.001    0.000 artist.py:828(get_visible)
#     47763    0.010    0.000    0.010    0.000 artist.py:832(get_animated)
#       234    0.000    0.000    0.000    0.000 artist.py:836(get_in_layout)
#       306    0.000    0.000    0.000    0.000 artist.py:847(get_clip_on)
#       306    0.000    0.000    0.000    0.000 artist.py:851(get_clip_box)
#       297    0.000    0.000    0.000    0.000 artist.py:855(get_clip_path)
#       558    0.001    0.000    0.005    0.000 artist.py:886(_set_gc_clip)
#      3384    0.001    0.000    0.001    0.000 artist.py:896(get_rasterized)
#      3384    0.001    0.000    0.001    0.000 artist.py:921(get_agg_filter)
#       171    0.001    0.000    0.002    0.000 artist.py:960(set_alpha)
#         9    0.000    0.000    0.000    0.000 artist.py:978(_set_alpha_for_array)
#        36    0.000    0.000    0.000    0.000 axis.py:1015(_set_artist_props)
#       180    0.008    0.000    0.268    0.001 axis.py:1040(_update_ticks)
#       180    0.000    0.000    0.201    0.001 axis.py:1083(_get_tick_bboxes)
#       180    0.002    0.000    0.200    0.001 axis.py:1085(<listcomp>)
#       180    0.001    0.000    0.001    0.000 axis.py:1087(<listcomp>)
#        54    0.001    0.000    0.258    0.005 axis.py:1090(get_tightbbox)
#       108    0.000    0.000    0.004    0.000 axis.py:1115(<genexpr>)
#        54    0.001    0.000    0.001    0.000 axis.py:1135(<listcomp>)
#        36    0.001    0.000    0.409    0.011 axis.py:1150(draw)
#        18    0.000    0.000    0.301    0.017 axis.py:1199(get_majorticklabels)
#        18    0.000    0.000    0.000    0.000 axis.py:1202(<listcomp>)
#        18    0.000    0.000    0.000    0.000 axis.py:1203(<listcomp>)
#        18    0.000    0.000    0.301    0.017 axis.py:1213(get_ticklabels)
#       198    0.000    0.000    0.081    0.000 axis.py:1275(get_majorticklocs)
#       180    0.002    0.000    0.073    0.000 axis.py:1279(get_minorticklocs)
#       180    0.000    0.000    0.000    0.000 axis.py:1292(<listcomp>)
#       378    0.002    0.000    0.014    0.000 axis.py:1326(_get_tick_label_size)
#       108    0.001    0.000    0.029    0.000 axis.py:1338(_copy_tick_props)
#        36    0.000    0.000    0.000    0.000 axis.py:1352(get_major_locator)
#       198    0.001    0.000    0.301    0.002 axis.py:1368(get_major_ticks)
#       180    0.000    0.000    0.000    0.000 axis.py:1381(get_minor_ticks)
#        36    0.000    0.000    0.199    0.006 axis.py:1394(grid)
#        36    0.000    0.000    0.000    0.000 axis.py:1426(<dictcomp>)
#        36    0.000    0.000    0.001    0.000 axis.py:1437(update_units)
#       162    0.000    0.000    0.000    0.000 axis.py:148(<dictcomp>)
#        36    0.000    0.000    0.000    0.000 axis.py:1492(have_units)
#       396    0.000    0.000    0.002    0.000 axis.py:1495(convert_units)
#       108    0.000    0.000    0.000    0.000 axis.py:1512(set_units)
#       144    0.000    0.000    0.005    0.000 axis.py:1567(set_major_formatter)
#       144    0.000    0.000    0.003    0.000 axis.py:1593(set_minor_formatter)
#       288    0.002    0.000    0.007    0.000 axis.py:1607(_set_formatter)
#       144    0.001    0.000    0.003    0.000 axis.py:1633(set_major_locator)
#       144    0.001    0.000    0.003    0.000 axis.py:1649(set_minor_locator)
#        90    0.001    0.000    0.183    0.002 axis.py:1860(_get_tick_boxes_siblings)
#        90    0.000    0.000    0.000    0.000 axis.py:1868(<listcomp>)
#       162    0.001    0.000    0.001    0.000 axis.py:190(_set_labelrotation)
#       108    0.000    0.000    0.001    0.000 axis.py:1922(_get_ticks_position)
#       324    0.000    0.000    0.001    0.000 axis.py:1938(<genexpr>)
#       108    0.000    0.000    0.000    0.000 axis.py:1959(get_label_position)
#      1458    0.002    0.000    0.029    0.000 axis.py:1985(getter)
#         9    0.000    0.000    0.022    0.002 axis.py:2013(__init__)
#       162    0.001    0.000    0.002    0.000 axis.py:202(_apply_tickdir)
#        81    0.001    0.000    0.284    0.004 axis.py:2052(_get_tick)
#        45    0.001    0.000    0.112    0.002 axis.py:2073(_update_label_position)
#        45    0.000    0.000    0.011    0.000 axis.py:2116(_update_offset_text_position)
#       162    0.000    0.000    0.000    0.000 axis.py:222(get_tick_padding)
#       108    0.000    0.000    0.001    0.000 axis.py:2226(get_ticks_position)
#        18    0.000    0.000    0.000    0.000 axis.py:2239(get_minpos)
#       189    0.003    0.000    0.041    0.000 axis.py:2261(get_tick_space)
#         9    0.000    0.000    0.022    0.002 axis.py:2279(__init__)
#        81    0.001    0.000    0.201    0.002 axis.py:2320(_get_tick)
#        45    0.001    0.000    0.107    0.002 axis.py:2342(_update_label_position)
#        54    0.000    0.000    0.028    0.001 axis.py:236(set_clip_path)
#        45    0.000    0.000    0.001    0.000 axis.py:2384(_update_offset_text_position)
#        18    0.000    0.000    0.000    0.000 axis.py:2501(get_minpos)
#       189    0.003    0.000    0.038    0.000 axis.py:2523(get_tick_space)
#      1440    0.000    0.000    0.000    0.000 axis.py:287(get_loc)
#       216    0.002    0.000    0.125    0.001 axis.py:291(draw)
#      1440    0.001    0.000    0.006    0.000 axis.py:303(set_label1)
#      1440    0.001    0.000    0.006    0.000 axis.py:316(set_label2)
#       810    0.001    0.000    0.005    0.000 axis.py:340(_set_artist_props)
#       126    0.002    0.000    0.026    0.000 axis.py:349(_apply_params)
#       630    0.000    0.000    0.000    0.000 axis.py:357(<genexpr>)
#       126    0.000    0.000    0.000    0.000 axis.py:374(<dictcomp>)
#       126    0.000    0.000    0.000    0.000 axis.py:387(<dictcomp>)
#       126    0.000    0.000    0.000    0.000 axis.py:392(<dictcomp>)
#        81    0.002    0.000    0.283    0.003 axis.py:414(__init__)
#        81    0.000    0.000    0.005    0.000 axis.py:436(_get_text1_transform)
#        81    0.000    0.000    0.004    0.000 axis.py:439(_get_text2_transform)
#        81    0.001    0.000    0.011    0.000 axis.py:442(_apply_tickdir)
#       801    0.003    0.000    0.011    0.000 axis.py:453(update_position)
#        81    0.002    0.000    0.200    0.002 axis.py:475(__init__)
#        81    0.000    0.000    0.005    0.000 axis.py:497(_get_text1_transform)
#        81    0.000    0.000    0.004    0.000 axis.py:500(_get_text2_transform)
#        81    0.001    0.000    0.014    0.000 axis.py:503(_apply_tickdir)
#       801    0.003    0.000    0.010    0.000 axis.py:514(update_position)
#        36    0.000    0.000    0.000    0.000 axis.py:541(__init__)
#       594    0.000    0.000    0.000    0.000 axis.py:547(locator)
#       288    0.000    0.000    0.001    0.000 axis.py:551(locator)
#      1368    0.000    0.000    0.000    0.000 axis.py:558(formatter)
#       288    0.000    0.000    0.000    0.000 axis.py:562(formatter)
#       162    0.010    0.000    0.301    0.002 axis.py:57(__init__)
#     54/36    0.000    0.000    0.229    0.006 axis.py:581(__get__)
#        18    0.001    0.000    0.035    0.002 axis.py:638(__init__)
#       288    0.000    0.000    0.000    0.000 axis.py:687(isDefault_majloc)
#       288    0.000    0.000    0.000    0.000 axis.py:695(isDefault_majfmt)
#       288    0.000    0.000    0.000    0.000 axis.py:703(isDefault_minloc)
#       288    0.000    0.000    0.000    0.000 axis.py:711(isDefault_minfmt)
#       180    0.000    0.000    0.000    0.000 axis.py:721(get_remove_overlapping_locs)
#      1746    0.001    0.000    0.004    0.000 axis.py:752(get_transform)
#        36    0.000    0.000    0.000    0.000 axis.py:755(get_scale)
#       144    0.001    0.000    0.071    0.000 axis.py:759(_set_scale)
#        36    0.000    0.000    0.000    0.000 axis.py:771(limit_range_for_scale)
#       108    0.001    0.000    0.057    0.001 axis.py:790(clear)
#       144    0.001    0.000    0.001    0.000 axis.py:830(reset_ticks)
#        72    0.001    0.000    0.211    0.003 axis.py:850(set_tick_params)
#        72    0.000    0.000    0.001    0.000 axis.py:889(_translate_tick_kw)
#        18    0.000    0.000    0.081    0.005 axis.py:934(set_clip_path)
#        18    0.000    0.000    0.000    0.000 backend_agg.py:109(_update_methods)
#        54    0.000    0.000    0.003    0.000 backend_agg.py:133(draw_path)
#       108    0.001    0.000    0.012    0.000 backend_agg.py:224(draw_text)
#       432    0.002    0.000    0.069    0.000 backend_agg.py:251(get_text_width_height_descent)
#       216    0.000    0.000    0.000    0.000 backend_agg.py:295(get_canvas_width_height)
#       540    0.002    0.000    0.051    0.000 backend_agg.py:299(_get_agg_font)
#       432    0.000    0.000    0.000    0.000 backend_agg.py:312(points_to_pixels)
#         9    0.000    0.000    0.000    0.000 backend_agg.py:316(buffer_rgba)
#        36    0.000    0.000    0.000    0.000 backend_agg.py:328(option_image_nocomposite)
#        18    0.000    0.000    0.000    0.000 backend_agg.py:336(option_scale_image)
#        18    0.000    0.000    0.235    0.013 backend_agg.py:429(draw)
#        18    0.000    0.000    0.003    0.000 backend_agg.py:441(get_renderer)
#         9    0.000    0.000    0.000    0.000 backend_agg.py:471(buffer_rgba)
#        18    0.000    0.000    0.275    0.015 backend_agg.py:490(print_png)
#       540    0.001    0.000    0.002    0.000 backend_agg.py:52(get_hinting_flag)
#        18    0.002    0.000    0.003    0.000 backend_agg.py:87(__init__)
#       279    0.000    0.000    0.000    0.000 backend_bases.py:1004(get_hatch_color)
#       279    0.000    0.000    0.000    0.000 backend_bases.py:1012(get_hatch_linewidth)
#       279    0.000    0.000    0.000    0.000 backend_bases.py:1016(get_sketch_params)
#        18    0.000    0.000    0.000    0.000 backend_bases.py:1227(__init__)
#        18    0.000    0.000    0.000    0.000 backend_bases.py:1255(__init__)
#         9    0.000    0.000    0.004    0.000 backend_bases.py:1519(_get_renderer)
#         9    0.000    0.000    0.000    0.000 backend_bases.py:1530(Done)
#         9    0.000    0.000    0.000    0.000 backend_bases.py:1533(_draw)
#        18    0.000    0.000    0.277    0.015 backend_bases.py:1595(wrapper)
#        18    0.000    0.000    0.000    0.000 backend_bases.py:1689(__init__)
#        18    0.000    0.000    0.000    0.000 backend_bases.py:170(__init__)
#        54    0.000    0.000    0.000    0.000 backend_bases.py:1710(<lambda>)
#        18    0.000    0.000    0.000    0.000 backend_bases.py:1748(is_saving)
#       414    0.000    0.000    0.000    0.000 backend_bases.py:177(open_group)
#        18    0.000    0.000    0.000    0.000 backend_bases.py:1770(draw_event)
#       414    0.000    0.000    0.000    0.000 backend_bases.py:184(close_group)
#         9    0.000    0.000    0.000    0.000 backend_bases.py:2030(draw)
#         9    0.000    0.000    0.000    0.000 backend_bases.py:2151(_get_output_canvas)
#         9    0.001    0.000    0.930    0.103 backend_bases.py:2187(print_figure)
#        27    0.000    0.000    0.001    0.000 backend_bases.py:2384(mpl_connect)
#         9    0.000    0.000    0.000    0.000 backend_bases.py:2439(mpl_disconnect)
#         9    0.000    0.000    0.001    0.000 backend_bases.py:2771(__init__)
#         9    0.000    0.000    0.000    0.000 backend_bases.py:2790(notify_axes_change)
#         9    0.000    0.000    0.000    0.000 backend_bases.py:2814(destroy)
#         9    0.000    0.000    0.000    0.000 backend_bases.py:2847(set_window_title)
#         9    0.000    0.000    0.009    0.001 backend_bases.py:3467(new_figure_manager)
#         9    0.000    0.000    0.001    0.000 backend_bases.py:3476(new_figure_manager_given_figure)
#        18    0.000    0.000    0.000    0.000 backend_bases.py:452(get_image_magnification)
#       216    0.000    0.000    0.000    0.000 backend_bases.py:639(flipy)
#       558    0.001    0.000    0.010    0.000 backend_bases.py:658(new_gc)
#         9    0.000    0.000    0.001    0.000 backend_bases.py:714(_draw_disabled)
#         9    0.000    0.000    0.000    0.000 backend_bases.py:722(<dictcomp>)
#      1107    0.000    0.000    0.000    0.000 backend_bases.py:723(<lambda>)
#       558    0.003    0.000    0.009    0.000 backend_bases.py:735(__init__)
#       558    0.000    0.000    0.000    0.000 backend_bases.py:776(restore)
#       279    0.000    0.000    0.000    0.000 backend_bases.py:803(get_clip_path)
#       279    0.000    0.000    0.000    0.000 backend_bases.py:818(get_dashes)
#       279    0.000    0.000    0.000    0.000 backend_bases.py:858(get_snap)
#       342    0.000    0.000    0.000    0.000 backend_bases.py:869(set_alpha)
#       324    0.000    0.000    0.000    0.000 backend_bases.py:886(set_antialiased)
#       324    0.000    0.000    0.001    0.000 backend_bases.py:891(set_capstyle)
#        18    0.000    0.000    0.000    0.000 backend_bases.py:902(set_clip_rectangle)
#       558    0.001    0.000    0.004    0.000 backend_bases.py:906(set_clip_path)
#       108    0.000    0.000    0.000    0.000 backend_bases.py:911(set_dashes)
#       882    0.000    0.000    0.001    0.000 backend_bases.py:935(set_foreground)
#       324    0.000    0.000    0.001    0.000 backend_bases.py:955(set_joinstyle)
#       324    0.000    0.000    0.000    0.000 backend_bases.py:966(set_linewidth)
#       558    0.000    0.000    0.000    0.000 backend_bases.py:970(set_url)
#        18    0.000    0.000    0.000    0.000 backend_bases.py:974(set_gid)
#       324    0.000    0.000    0.000    0.000 backend_bases.py:978(set_snap)
#       279    0.000    0.000    0.000    0.000 backend_bases.py:993(get_hatch)
#       279    0.000    0.000    0.000    0.000 backend_bases.py:997(get_hatch_path)
#         9    0.000    0.000    0.304    0.034 backend_inline.py:226(_fetch_figure_metadata)
#         9    0.000    0.000    1.256    0.140 backend_inline.py:23(show)
#         9    0.000    0.000    0.301    0.033 backend_inline.py:231(<listcomp>)
#         9    0.000    0.000    0.002    0.000 backend_inline.py:242(_is_light)
#         9    0.000    0.000    0.000    0.000 backend_inline.py:250(_is_transparent)
#         9    0.000    0.000    0.000    0.000 backend_inline.py:59(draw_if_interactive)
#      1583    0.007    0.000   29.211    0.018 basic.py:106(fft2)
#      1553    0.006    0.000    2.616    0.002 basic.py:117(ifft2)
#      3136    0.041    0.000   31.814    0.010 basic.py:172(c2cn)
#        65    0.001    0.000    0.004    0.000 basics.py:257(op)
#        18    0.000    0.000    0.001    0.000 basics.py:270(cop)
#      1553    0.007    0.000    5.427    0.003 basics.py:280(<lambda>)
#        25    0.000    0.000    0.002    0.000 basics.py:282(diagop)
#       397    0.061    0.000    0.062    0.000 basics.py:293(<lambda>)
#      1553    0.597    0.000    5.281    0.003 basics.py:79(conv)
#        30    0.000    0.000    0.000    0.000 blas.py:383(getter)
#        18    0.000    0.000    0.001    0.000 cm.py:259(get_cmap)
#        18    0.000    0.000    0.002    0.000 cm.py:342(__init__)
#         9    0.000    0.000    0.003    0.000 cm.py:367(_scale_norm)
#        18    0.000    0.000    0.017    0.001 cm.py:389(to_rgba)
#        18    0.000    0.000    0.000    0.000 cm.py:482(get_array)
#         9    0.000    0.000    0.000    0.000 cm.py:501(set_clim)
#        18    0.000    0.000    0.001    0.000 cm.py:537(set_cmap)
#       261    0.000    0.000    0.000    0.000 cm.py:551(norm)
#        18    0.000    0.000    0.001    0.000 cm.py:555(norm)
#        18    0.000    0.000    0.001    0.000 cm.py:575(set_norm)
#         9    0.000    0.000    0.003    0.000 cm.py:602(autoscale_None)
#        18    0.000    0.000    0.000    0.000 cm.py:613(changed)
#      3762    0.004    0.000    0.018    0.000 colors.py:106(_is_nth_color)
#       891    0.002    0.000    0.014    0.000 colors.py:111(is_color_like)
#        18    0.000    0.000    0.000    0.000 colors.py:1113(__init__)
#       135    0.000    0.000    0.000    0.000 colors.py:1141(vmin)
#        45    0.000    0.000    0.001    0.000 colors.py:1145(vmin)
#       117    0.000    0.000    0.000    0.000 colors.py:1152(vmax)
#        45    0.000    0.000    0.000    0.000 colors.py:1156(vmax)
#        18    0.000    0.000    0.000    0.000 colors.py:1163(clip)
#        18    0.000    0.000    0.001    0.000 colors.py:1173(_changed)
#        54    0.000    0.000    0.004    0.000 colors.py:1180(process_value)
#        18    0.002    0.000    0.007    0.000 colors.py:1215(__call__)
#       891    0.002    0.000    0.016    0.000 colors.py:124(_check_color_like)
#        45    0.000    0.000    0.003    0.000 colors.py:1278(autoscale_None)
#      2871    0.005    0.000    0.020    0.000 colors.py:152(to_rgba)
#         9    0.000    0.000    0.000    0.000 colors.py:195(_to_rgba_no_colorcycle)
#         9    0.000    0.000    0.001    0.000 colors.py:287(to_rgba_array)
#         9    0.000    0.000    0.000    0.000 colors.py:369(<setcomp>)
#         9    0.000    0.000    0.001    0.000 colors.py:375(<listcomp>)
#        18    0.006    0.000    0.016    0.001 colors.py:589(__call__)
#       126    0.000    0.000    0.000    0.000 colors.py:96(_sanitize_extrema)
#        36    0.000    0.000    0.000    0.000 configurable.py:510(instance)
#        18    0.000    0.000    0.000    0.000 configurable.py:554(initialized)
# 4788/4545    0.005    0.000    0.129    0.000 contextlib.py:108(__enter__)
# 4788/4545    0.007    0.000    0.032    0.000 contextlib.py:117(__exit__)
#      4788    0.005    0.000    0.017    0.000 contextlib.py:238(helper)
#        27    0.000    0.000    0.000    0.000 contextlib.py:375(_create_exit_wrapper)
#         9    0.000    0.000    0.000    0.000 contextlib.py:385(__init__)
#        27    0.000    0.000    0.002    0.000 contextlib.py:415(enter_context)
#        27    0.000    0.000    0.000    0.000 contextlib.py:458(_push_cm_exit)
#        27    0.000    0.000    0.000    0.000 contextlib.py:463(_push_exit_callback)
#         9    0.000    0.000    0.000    0.000 contextlib.py:479(__enter__)
#         9    0.000    0.000    0.001    0.000 contextlib.py:482(__exit__)
#        18    0.000    0.000    0.000    0.000 contextlib.py:697(__init__)
#        18    0.000    0.000    0.000    0.000 contextlib.py:700(__enter__)
#        18    0.000    0.000    0.000    0.000 contextlib.py:703(__exit__)
#      4788    0.010    0.000    0.012    0.000 contextlib.py:82(__init__)
#         9    0.000    0.000    0.000    0.000 copy.py:258(_reconstruct)
#         9    0.000    0.000    0.000    0.000 copy.py:66(copy)
#         9    0.000    0.000    0.000    0.000 copyreg.py:90(__newobj__)
#       106    0.000    0.000    0.000    0.000 core.py:1278(_replace_dtype_fields_recursive)
#       106    0.000    0.000    0.000    0.000 core.py:1310(_replace_dtype_fields)
#       106    0.000    0.000    0.000    0.000 core.py:1324(make_mask_descr)
#       277    0.000    0.000    0.000    0.000 core.py:1357(getmask)
#         9    0.000    0.000    0.000    0.000 core.py:1540(_shrink_mask)
#        54    0.000    0.000    0.001    0.000 core.py:1812(_check_mask_axis)
#        54    0.000    0.000    0.000    0.000 core.py:200(_recursive_fill_value)
#        54    0.000    0.000    0.000    0.000 core.py:215(_get_dtype_of)
#         9    0.000    0.000    0.001    0.000 core.py:2330(masked_invalid)
#        54    0.000    0.000    0.001    0.000 core.py:280(_extremum_fill_value)
#       106    0.001    0.000    0.004    0.000 core.py:2813(__new__)
#        54    0.000    0.000    0.000    0.000 core.py:282(_scalar_fill_value)
#        27    0.000    0.000    0.001    0.000 core.py:294(minimum_fill_value)
#       169    0.001    0.000    0.002    0.000 core.py:2944(_update_from)
#       169    0.001    0.000    0.003    0.000 core.py:2970(__array_finalize__)
#        72    0.000    0.000    0.000    0.000 core.py:3209(__getitem__)
#        36    0.000    0.000    0.000    0.000 core.py:3226(_scalar_heuristic)
#       563    0.000    0.000    0.000    0.000 core.py:3401(dtype)
#       169    0.000    0.000    0.000    0.000 core.py:3417(shape)
#        27    0.000    0.000    0.000    0.000 core.py:345(maximum_fill_value)
#        70    0.000    0.000    0.000    0.000 core.py:3500(mask)
#         9    0.000    0.000    0.000    0.000 core.py:3597(shrink_mask)
#       178    0.000    0.000    0.000    0.000 core.py:3633(_get_data)
#        54    0.000    0.000    0.002    0.000 core.py:3727(filled)
#        54    0.000    0.000    0.000    0.000 core.py:428(_check_fill_value)
#        27    0.000    0.000    0.003    0.000 core.py:5657(min)
#        27    0.000    0.000    0.002    0.000 core.py:5791(max)
#       126    0.000    0.000    0.000    0.000 core.py:582(filled)
#        70    0.000    0.000    0.003    0.000 core.py:6546(array)
#        18    0.000    0.000    0.000    0.000 core.py:6563(is_masked)
#        18    0.000    0.000    0.001    0.000 core.py:7905(asarray)
#       108    0.000    0.000    0.000    0.000 cycler.py:165(keys)
#      1006    0.002    0.000    0.002    0.000 cycler.py:239(__iter__)
#        90    0.001    0.000    0.003    0.000 cycler.py:364(by_key)
#        90    0.000    0.000    0.000    0.000 cycler.py:386(<dictcomp>)
#        30    2.538    0.085    2.678    0.089 decomp_cholesky.py:13(_cholesky)
#        30    0.000    0.000    2.678    0.089 decomp_cholesky.py:45(cholesky)
#       108    0.000    0.000    0.004    0.000 decorator.py:199(fix)
#       108    0.000    0.000    0.940    0.009 decorator.py:229(fun)
#         9    0.000    0.000    0.000    0.000 decorators.py:41(wrapper)
#   144/108    0.000    0.000    0.201    0.002 deprecation.py:291(wrapper)
#        27    0.000    0.000    0.280    0.010 deprecation.py:381(wrapper)
#        54    0.000    0.000    0.000    0.000 deprecation.py:400(<genexpr>)
#      27/9    0.012    0.000    0.475    0.053 deprecation.py:445(wrapper)
#        90    0.000    0.000    0.000    0.000 dir2.py:54(get_real_method)
#         9    0.000    0.000    0.948    0.105 display.py:131(display)
#         9    0.000    0.000    0.014    0.002 display.py:1462(clear_output)
#      18/9    0.000    0.000    0.000    0.000 display.py:41(_merge)
#         9    0.000    0.000    0.007    0.001 display.py:81(publish_display_data)
#         9    0.000    0.000    0.000    0.000 displaypub.py:43(_validate_data)
#        72    0.000    0.000    0.000    0.000 encoder.py:104(__init__)
#        72    0.000    0.000    0.002    0.000 encoder.py:182(encode)
#        72    0.001    0.000    0.002    0.000 encoder.py:204(iterencode)
#      3852    0.004    0.000    0.005    0.000 enum.py:313(__call__)
#      3852    0.002    0.000    0.002    0.000 enum.py:631(__new__)
#        36    0.000    0.000    0.000    0.000 figure.py:100(__call__)
#        18    0.000    0.000    0.000    0.000 figure.py:112(__contains__)
#         9    0.000    0.000    0.000    0.000 figure.py:121(__init__)
#         9    0.000    0.000    0.000    0.000 figure.py:1477(sca)
#        18    0.000    0.000    0.444    0.025 figure.py:1483(gca)
#         9    0.000    0.000    0.000    0.000 figure.py:1548(_process_projection_requirements)
#        18    0.000    0.000    0.000    0.000 figure.py:155(update)
#         9    0.000    0.000    0.001    0.000 figure.py:1586(get_default_bbox_extra_artists)
#         9    0.000    0.000    0.000    0.000 figure.py:1587(<listcomp>)
#         9    0.001    0.000    0.331    0.037 figure.py:1594(get_tightbbox)
#         9    0.000    0.000    0.001    0.000 figure.py:1642(<listcomp>)
#         9    0.000    0.000    0.001    0.000 figure.py:186(__init__)
#         9    0.000    0.000    0.000    0.000 figure.py:1921(_set_artist_props)
#         9    0.000    0.000    0.000    0.000 figure.py:2140(__repr__)
#         9    0.001    0.000    0.008    0.001 figure.py:2147(__init__)
#        18    0.000    0.000    0.007    0.000 figure.py:218(_get_draw_artists)
#        36    0.000    0.000    0.000    0.000 figure.py:230(<genexpr>)
#        18    0.000    0.000    0.000    0.000 figure.py:231(<lambda>)
#         9    0.000    0.000    0.000    0.000 figure.py:2318(_repr_html_)
#        81    0.000    0.000    0.000    0.000 figure.py:2362(axes)
#      4509    0.001    0.000    0.001    0.000 figure.py:2378(_get_dpi)
#      2736    0.001    0.000    0.001    0.000 figure.py:2381(_set_dpi)
#        27    0.000    0.000    0.000    0.000 figure.py:2401(get_tight_layout)
#        27    0.000    0.000    0.000    0.000 figure.py:2405(set_tight_layout)
#        36    0.000    0.000    0.000    0.000 figure.py:2423(get_constrained_layout)
#        27    0.000    0.000    0.000    0.000 figure.py:2431(set_constrained_layout)
#        27    0.000    0.000    0.000    0.000 figure.py:2461(set_constrained_layout_pads)
#        27    0.000    0.000    0.000    0.000 figure.py:2526(set_canvas)
#         9    0.000    0.000    0.000    0.000 figure.py:2743(clf)
#        18    0.000    0.000    0.540    0.030 figure.py:2779(draw)
#         9    0.000    0.000    0.000    0.000 figure.py:2883(add_axobserver)
#         9    0.000    0.000    0.000    0.000 figure.py:2887(<lambda>)
#        27    0.000    0.000    0.000    0.000 figure.py:293(get_children)
#        18    0.000    0.000    0.000    0.000 figure.py:431(get_edgecolor)
#        27    0.000    0.000    0.000    0.000 figure.py:435(get_facecolor)
#      5121    0.002    0.000    0.005    0.000 figure.py:46(_stale_figure_callback)
#        18    0.000    0.000    0.000    0.000 figure.py:463(set_edgecolor)
#        18    0.000    0.000    0.000    0.000 figure.py:473(set_facecolor)
#        18    0.000    0.000    0.000    0.000 figure.py:61(__init__)
#         9    0.000    0.000    0.444    0.049 figure.py:646(add_subplot)
#       144    0.000    0.000    0.001    0.000 figure.py:65(as_list)
#       144    0.000    0.000    0.000    0.000 figure.py:69(<listcomp>)
#         9    0.000    0.000    0.000    0.000 figure.py:71(_entry_from_axes)
#        18    0.000    0.000    0.000    0.000 figure.py:72(<genexpr>)
# ...
#        18    0.000    0.000    0.000    0.000 widgets.py:36(__init__)
#         9    0.000    0.000    0.014    0.002 zmqshell.py:142(clear_output)
#        18    0.000    0.000    0.014    0.001 zmqshell.py:70(_flush_streams)
#         9    0.000    0.000    0.000    0.000 zmqshell.py:80(_hooks)
#         9    0.000    0.000    0.007    0.001 zmqshell.py:87(publish)
#         9    0.000    0.000    0.000    0.000 {built-in method PIL._imaging.fill}
#         9    0.000    0.000    0.000    0.000 {built-in method PIL._imaging.map_buffer}
#         9    0.000    0.000    0.000    0.000 {built-in method PIL._imaging.zip_encoder}
#      2543    0.002    0.000    0.002    0.000 {built-in method __new__ of type object at 0x908780}
#     11059    0.011    0.000    0.012    0.000 {built-in method _abc._abc_instancecheck}
#       279    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#        36    0.000    0.000    0.000    0.000 {built-in method _imp.lock_held}
#      7308    0.002    0.000    0.002    0.000 {built-in method _operator.index}
#         1    0.000    0.000    0.000    0.000 {built-in method _stat.S_ISREG}
#       126    0.000    0.000    0.000    0.000 {built-in method _struct.pack}
#        54    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#       540    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#         9    0.000    0.000    0.000    0.000 {built-in method binascii.b2a_base64}
#         9    0.000    0.000    0.000    0.000 {built-in method builtins.__build_class__}
#      8379    0.018    0.000    0.018    0.000 {built-in method builtins.abs}
#       486    0.001    0.000    0.002    0.000 {built-in method builtins.all}
#     12338    0.016    0.000    0.026    0.000 {built-in method builtins.any}
#      5373    0.002    0.000    0.002    0.000 {built-in method builtins.callable}
#      2925    0.001    0.000    0.001    0.000 {built-in method builtins.delattr}
#         9    0.000    0.000    0.000    0.000 {built-in method builtins.dir}
#       756    0.000    0.000    0.000    0.000 {built-in method builtins.divmod}
#         1    0.000    0.000  142.992  142.992 {built-in method builtins.exec}
#     48520    0.029    0.000    0.056    0.000 {built-in method builtins.getattr}
#      7799    0.004    0.000    0.004    0.000 {built-in method builtins.hasattr}
# 6550/3896    0.003    0.000    0.015    0.000 {built-in method builtins.hash}
#      7632    0.002    0.000    0.002    0.000 {built-in method builtins.id}
#     72740    0.031    0.000    0.049    0.000 {built-in method builtins.isinstance}
#      5919    0.002    0.000    0.002    0.000 {built-in method builtins.issubclass}
#      2237    0.002    0.000    0.002    0.000 {built-in method builtins.iter}
# 33806/33743    0.007    0.000    0.007    0.000 {built-in method builtins.len}
#        36    0.000    0.000    0.000    0.000 {built-in method builtins.locals}
#      3999    1.116    0.000    1.116    0.000 {built-in method builtins.max}
#       958    0.001    0.000    0.001    0.000 {built-in method builtins.min}
# 10697/9725    0.008    0.000    0.148    0.000 {built-in method builtins.next}
#       113    0.002    0.000    0.037    0.000 {built-in method builtins.print}
#         9    0.000    0.000    0.000    0.000 {built-in method builtins.repr}
#       216    0.001    0.000    0.001    0.000 {built-in method builtins.round}
#      7623    0.005    0.000    0.006    0.000 {built-in method builtins.setattr}
#      1143    0.004    0.000    0.004    0.000 {built-in method builtins.sorted}
#        18    0.000    0.000    0.000    0.000 {built-in method builtins.sum}
#      1242    0.001    0.000    0.001    0.000 {built-in method builtins.vars}
#         9    0.004    0.000    0.004    0.000 {built-in method gc.collect}
#        36    0.000    0.000    0.000    0.000 {built-in method math.ceil}
#       522    0.000    0.000    0.000    0.000 {built-in method math.cos}
#       720    0.000    0.000    0.000    0.000 {built-in method math.floor}
#      1098    0.001    0.000    0.001    0.000 {built-in method math.log10}
#       630    0.000    0.000    0.000    0.000 {built-in method math.radians}
#       522    0.000    0.000    0.000    0.000 {built-in method math.sin}
#        36    0.027    0.001    0.029    0.001 {built-in method matplotlib._image.resample}
#      2862    0.004    0.000    0.004    0.000 {built-in method matplotlib._path.affine_transform}
#         9    0.000    0.000    0.000    0.000 {built-in method matplotlib._path.update_path_extents}
#       378    0.002    0.000    0.002    0.000 {built-in method numpy.arange}
#     36713    0.086    0.000    0.086    0.000 {built-in method numpy.array}
# 27938/23422    0.761    0.000    5.055    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#       216    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.normalize_axis_index}
#        72    0.000    0.000    0.000    0.000 {built-in method numpy.empty}
#        72    0.000    0.000    0.000    0.000 {built-in method numpy.geterrobj}
#        36    0.000    0.000    0.000    0.000 {built-in method numpy.seterrobj}
#       234    0.006    0.000    0.006    0.000 {built-in method numpy.zeros}
#       297    0.000    0.000    0.000    0.000 {built-in method posix.fspath}
#       454    0.001    0.000    0.001    0.000 {built-in method posix.getpid}
#         1    0.000    0.000    0.000    0.000 {built-in method posix.stat}
#      3136   31.599    0.010   31.599    0.010 {built-in method scipy.fft._pocketfft.pypocketfft.c2c}
#        18    0.000    0.000    0.000    0.000 {built-in method sys._getframe}
#         9    0.000    0.000    0.000    0.000 {built-in method sys.exc_info}
#      1584    0.001    0.000    0.001    0.000 {built-in method sys.intern}
#         9    0.000    0.000    0.000    0.000 {built-in method sys.is_finalizing}
#         9    0.000    0.000    0.000    0.000 {built-in method time.time}
#        18    0.000    0.000    0.000    0.000 {built-in method utcnow}
#        90    0.000    0.000    0.000    0.000 {built-in method zlib.crc32}
#     44944    0.011    0.000    0.011    0.000 {function RcParams.__getitem__ at 0x7fd0c748fb80}
#        27    0.000    0.000    0.000    0.000 {method '__array_prepare__' of 'numpy.ndarray' objects}
#        36    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#        36    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         9    0.000    0.000    0.000    0.000 {method '__reduce_ex__' of 'object' objects}
#       679    0.004    0.000    0.004    0.000 {method 'acquire' of '_thread.lock' objects}
#        18    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#       102    0.000    0.000    0.030    0.000 {method 'all' of 'numpy.ndarray' objects}
#        90    0.000    0.000    0.001    0.000 {method 'any' of 'numpy.ndarray' objects}
#       616    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#     12595    0.003    0.000    0.003    0.000 {method 'append' of 'list' objects}
#        22    0.000    0.000    0.000    0.000 {method 'argmin' of 'numpy.ndarray' objects}
#        36    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.generic' objects}
#       441    0.073    0.000    0.073    0.000 {method 'astype' of 'numpy.ndarray' objects}
#         9    0.000    0.000    0.000    0.000 {method 'cleanup' of 'ImagingEncoder' objects}
#         9    0.000    0.000    0.000    0.000 {method 'clear' of 'collections.OrderedDict' objects}
#         9    0.000    0.000    0.000    0.000 {method 'clear' of 'collections.deque' objects}
#       540    0.000    0.000    0.000    0.000 {method 'clear' of 'matplotlib.ft2font.FT2Font' objects}
#       398    0.001    0.000    0.014    0.000 {method 'clip' of 'numpy.ndarray' objects}
#         9    0.000    0.000    0.000    0.000 {method 'copy' of 'ImagingCore' objects}
#        54    0.000    0.000    0.000    0.000 {method 'copy' of '_hashlib.HASH' objects}
#        36    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#      1089    0.000    0.000    0.000    0.000 {method 'copy' of 'list' objects}
#        36    0.000    0.000    0.000    0.000 {method 'copy' of 'numpy.generic' objects}
#      9468    0.014    0.000    0.014    0.000 {method 'copy' of 'numpy.ndarray' objects}
#      1836    0.001    0.000    0.001    0.000 {method 'count' of 'str' objects}
#        18    0.000    0.000    0.000    0.000 {method 'cumsum' of 'numpy.ndarray' objects}
#         9    0.000    0.000    0.000    0.000 {method 'decode' of 'bytes' objects}
#        18    0.000    0.000    0.000    0.000 {method 'diagonal' of 'numpy.ndarray' objects}
#        18    0.000    0.000    0.000    0.000 {method 'digest' of '_hashlib.HASH' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#        18    0.000    0.000    0.000    0.000 {method 'discard' of 'set' objects}
#         9    0.000    0.000    0.000    0.000 {method 'dot' of 'numpy.ndarray' objects}
#       108    0.001    0.000    0.001    0.000 {method 'draw_glyphs_to_bitmap' of 'matplotlib.ft2font.FT2Font' objects}
#         9    0.001    0.000    0.001    0.000 {method 'draw_image' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#       108    0.003    0.000    0.004    0.000 {method 'draw_markers' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#        54    0.002    0.000    0.002    0.000 {method 'draw_path' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#       108    0.001    0.000    0.002    0.000 {method 'draw_text_image' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#         9    0.037    0.004    0.037    0.004 {method 'encode' of 'ImagingEncoder' objects}
#       108    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#       225    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 {method 'fill' of 'numpy.ndarray' objects}
#       162    0.000    0.000    0.000    0.000 {method 'flatten' of 'numpy.ndarray' objects}
#         9    0.000    0.000    0.000    0.000 {method 'flush' of '_io.BytesIO' objects}
#       207    0.001    0.000    0.001    0.000 {method 'format' of 'str' objects}
#     22809    0.005    0.000    0.005    0.000 {method 'get' of 'dict' objects}
#         9    0.000    0.000    0.000    0.000 {method 'get' of 'mappingproxy' objects}
#       108    0.000    0.000    0.000    0.000 {method 'get_bitmap_offset' of 'matplotlib.ft2font.FT2Font' objects}
#       540    0.000    0.000    0.000    0.000 {method 'get_descent' of 'matplotlib.ft2font.FT2Font' objects}
#       432    0.000    0.000    0.000    0.000 {method 'get_width_height' of 'matplotlib.ft2font.FT2Font' objects}
#         9    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.BytesIO' objects}
#         9    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.StringIO' objects}
#        18    0.000    0.000    0.000    0.000 {method 'hexdigest' of '_hashlib.HASH' objects}
#        42    0.000    0.000    0.000    0.000 {method 'index' of 'list' objects}
#         9    0.000    0.000    0.000    0.000 {method 'indices' of 'slice' objects}
#         9    0.000    0.000    0.000    0.000 {method 'islower' of 'bytes' objects}
#        36    0.000    0.000    0.000    0.000 {method 'isoformat' of 'datetime.datetime' objects}
#        90    0.000    0.000    0.000    0.000 {method 'item' of 'numpy.generic' objects}
#     48270    0.009    0.000    0.009    0.000 {method 'items' of 'dict' objects}
#       324    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
#        45    0.000    0.000    0.000    0.000 {method 'join' of 'bytes' objects}
#       216    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#         9    0.000    0.000    0.000    0.000 {method 'ljust' of 'str' objects}
#      4676    0.001    0.000    0.001    0.000 {method 'lower' of 'str' objects}
#       144    0.000    0.000    0.000    0.000 {method 'lstrip' of 'str' objects}
#      3744    0.004    0.000    0.004    0.000 {method 'match' of 're.Pattern' objects}
#      2502    0.002    0.000    0.011    0.000 {method 'max' of 'numpy.ndarray' objects}
#      1062    0.001    0.000    0.008    0.000 {method 'min' of 'numpy.ndarray' objects}
#         9    0.000    0.000    0.000    0.000 {method 'move_to_end' of 'collections.OrderedDict' objects}
#      3136    0.004    0.000    0.004    0.000 {method 'newbyteorder' of 'numpy.dtype' objects}
#       378    0.001    0.000    0.001    0.000 {method 'nonzero' of 'numpy.ndarray' objects}
#        18    0.000    0.000    0.000    0.000 {method 'pixel_access' of 'ImagingCore' objects}
#         9    0.000    0.000    0.000    0.000 {method 'pop' of 'collections.OrderedDict' objects}
#        27    0.000    0.000    0.000    0.000 {method 'pop' of 'collections.deque' objects}
#      6624    0.002    0.000    0.002    0.000 {method 'pop' of 'dict' objects}
#        27    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#      4882    0.145    0.000    0.145    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#     14775    1.387    0.000    1.387    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#        18    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#       144    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#        18    0.000    0.000    0.000    0.000 {method 'replace' of 'datetime.datetime' objects}
#      1998    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#      9840    0.029    0.000    0.029    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#       144    0.000    0.000    0.000    0.000 {method 'reverse' of 'list' objects}
#        18    0.000    0.000    0.000    0.000 {method 'rfind' of 'str' objects}
#      1080    0.005    0.000    0.005    0.000 {method 'round' of 'numpy.ndarray' objects}
#       225    0.000    0.000    0.000    0.000 {method 'rpartition' of 'str' objects}
#       540    0.000    0.000    0.000    0.000 {method 'set_size' of 'matplotlib.ft2font.FT2Font' objects}
#       540    0.020    0.000    0.020    0.000 {method 'set_text' of 'matplotlib.ft2font.FT2Font' objects}
#       198    0.000    0.000    0.000    0.000 {method 'setdefault' of 'dict' objects}
#         9    0.000    0.000    0.000    0.000 {method 'setimage' of 'ImagingEncoder' objects}
#         9    0.000    0.000    0.000    0.000 {method 'sort' of 'list' objects}
#        81    0.000    0.000    0.000    0.000 {method 'sort' of 'numpy.ndarray' objects}
#       504    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#         9    0.000    0.000    0.000    0.000 {method 'splitlines' of 'str' objects}
#       504    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#       378    0.000    0.000    0.003    0.000 {method 'sum' of 'numpy.ndarray' objects}
#        18    0.005    0.000    0.005    0.000 {method 'take' of 'numpy.ndarray' objects}
#         9    0.001    0.000    0.001    0.000 {method 'trace' of 'numpy.ndarray' objects}
#        90    0.000    0.000    0.000    0.000 {method 'update' of '_hashlib.HASH' objects}
#      1934    0.002    0.000    0.002    0.000 {method 'update' of 'dict' objects}
#        18    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#        54    0.000    0.000    0.000    0.000 {method 'values' of 'collections.OrderedDict' objects}
#      5328    0.001    0.000    0.001    0.000 {method 'values' of 'dict' objects}
#       126    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#   205/151    0.001    0.000    0.001    0.000 {method 'view' of 'numpy.generic' objects}
#   381/363    0.000    0.000    0.002    0.000 {method 'view' of 'numpy.ndarray' objects}
#       144    0.000    0.000    0.000    0.000 {method 'write' of '_io.BytesIO' objects}
#         9    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}

# %%
bestP, bestβ = current_best()[:2]
μ,v,l = results[bestP,bestβ]
λ = exp(μ + μ0 + v/2)
subplot(121)
showim(λ.reshape(L,L),mask=mask)
subplot(122)
showim(1/v.reshape(L,L),mask=mask)
print('Optimized kernel height β=%f'%βs[bestβ])
print('Optimized kernel period P=%f'%Ps[bestP])
# Out:
# Optimized kernel height β=10.000000
# Optimized kernel period P=16.940001

# %%
'''
Use low-pass filtered velocity angle as heading 
Positive dx is eastwards
Negative dx is westwards
Positive dy is northwards
Negative dy is southwards
Angle is computed as if a complex number
North is +90, West is ±180, South is -90, and East is 0.
So, sin(θ) is the vertical direction, with sin(θ)=1 being northwards.
Likewise cos(θ) is the horizontal direction, with cos(θ)=1 being eastwards.
North: positive sin(θ)
South: negative sin(θ)
East : positive cos(θ)
West : negative cos(θ)
φ=0    : West
φ=1/2π : South
φ=π    : East
φ=3/2π : North
'''
φW,φS,φE,φN = 0, pi/2, pi, 3*pi/2
φs  = linspace(0,2*pi,90+1)[:-1]
φiW = argmin(abs(φs-φW))
φiS = argmin(abs(φs-φS))
φiE = argmin(abs(φs-φE))
φiN = argmin(abs(φs-φN))
