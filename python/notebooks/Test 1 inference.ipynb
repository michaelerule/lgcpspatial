# %%
# %load_ext autoreload
# %autoreload 2
from config import *

fn    = 'r2405_051216b_cell1816.mat'
data  = Dataset.from_file(datadir+fn).prepare()
arena = data.arena

# Used to locate peaks in the autocorrelogram
kf = kernelft(
    data.shape,
    data.P,
    data.V,
    angle=data.angle,
    style='grid')
result,model = lgcp2d(
    kf,
    data.N,
    data.K,
    data.prior_mean,
    (data.kdelograte,None),
    eps=1e-5,
    verbose=True)

arena.imshow(result.info.r,lw=8)
print(data.arena.meters_per_bin*100)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# μ iter 0, ε=3.2292e+01
# μ iter 1, ε=1.7771e+01
# μ iter 2, ε=2.9203e+00
# μ iter 3, ε=1.2636e-01
# μ iter 4, ε=1.3577e-03
# μ iter 5, ε=2.0932e-05
# μ iter 6, ε=1.2481e-06
# v iter 0, ε=9.1475e-02
# μ iter 0, ε=2.4122e+00
# μ iter 1, ε=3.2012e-02
# μ iter 2, ε=1.5278e-04
# μ iter 3, ε=2.3848e-06
# v iter 0, ε=1.3614e-04
# μ iter 0, ε=9.2803e-04
# μ iter 1, ε=4.9535e-06
# v iter 0, ε=5.6624e-07
# 1.831454914063215
